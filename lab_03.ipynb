# %% [markdown]
# Lab 3: Create-a-Quiz
# fig.trivia_quiz
# Now is your chance to write your own quiz. Use these quizzes to filter job applicants, weed out potential mates, or just plain have a chance to sit on the other side of the desk and make, rather than take, the quiz.
#
# This lab applies the material used in Chapter 3 on using if statements. It also requires a bit of Chapter 1 because the program must calculate a percentage.
#
# 3.1 Description
# This is the list of features your quiz needs to have:
#
# Create your own quiz with five or more questions. You can ask questions that require:
# a number as an answer (e.g., What is 1+1?)
# text (e.g. What is Harry Potter's last name?)
# a selection (Which of these choices are correct? A, B, or C?)
# If you have the user enter non-numeric answers, think and cover the different ways a user could enter a correct answer. For example, if the answer is “a”, would “A” also be acceptable? See Section 3.6 for a reminder on how to do this.
#
# Let the user know if he or she gets the question correct. Print a message depending on the user's answer.
#
# You need to keep track of how many questions they get correct.
#
# At the end of the program print the percentage of questions the user gets right.
#
# Keep the following in mind when creating the program:
#
# Variable names should start with a lower case letter. Upper case letters work, but it is not considered proper. (Right, you didn't realize that programming was going to be like English Tea Time, did you?)
# To create a running total of the number correct, create a variable to store this score. Set it to zero. With an if statement, add one to the variable each time the user gets a correct answer. (How do you know if they got it correct? Remember that if you are printing out “correct” then you have already done that part. Just add a line there to add one to the number correct.) If you don't remember how to add one to a variable, go back and review Section 1.5.
# Treat true/false questions like multiple choice questions, just compare to “True” or “False.” Don't try to do if a: we'll implement if statements like that later on in the class, but this isn't the place.
# Calculate the percentage by using a formula at the end of the game. Don't just add 20% for each question the user gets correct. If you add 20% each time, then you have to change the program 5 places if you add a 6th question. With a formula, you only need 1 change.
# To print a blank line so that all the questions don't run into each other, use the following code:
# print()
# Remember the program can print multiple items on one line. This can be useful when printing the user's score at the end.
# print("The value in x is", x)
# Separate out your code by using blank lines to group sections together. For example, put a blank line between the code for each question.
# Sometimes it makes sense to re-use variables. Rather than having a different variable to hold the user's answer for each question, you could reuse the same one.
# Use descriptive variable names. x is a terrible variable name. Instead use something like number_correct.
# Don't make super-long lines. Chances are you don't need to use \n at all. Just use multiple print statements.
# When you are done turn in the assignment according to your teacher/mentor's instructions.

# %%
# Lab 03 - With 4 active questions
# Quizz game program
# Requirements: 1) 5 questions minimum 2) Give feedback to user after they answer a question
# 3) Keep track of the number of correct answers 
# 4) At the end print the percentage of correct answers

# Welcome to the quizz game
print("Welcome to the quizz game!")
# Instructions to the user
print("Try to answer as many questions correct as possible.")
# What the user can expect
print("At the end of the quizz you will get your total score in percent of correct answers!")
print()

# Define variables to be used in the program
questions = 0 # Number of questions asked
correct_answers = 0 # Number of correct answers
correct = 0 # Set to True if the answer is correct
percentage = 0 # The percentage of correct answers is the total score

# Question 1 : Chakras - 7 options
# Input
print("Question 1:")
print("Which of these chakras is the heart chakra? ")
print("A: Muladhara Chakra")
print("B: Svadistana Chakra")
print("C: Manipura Chakra")
print("D: Anahata Chakra")
print("E: Vishuddha Chakra")
print("F: Ajna Chakra")
print("G: Sahasrara Chakra")
print()
answer = str(input())
# Calculations
questions += 1
if answer.upper() == "D":
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct_answers / questions) * 100)
# Output
if correct:
    print()
    print("You must be a yogi - the answer is correct!")
else:
    print()
    print("You should seriously consider practicing more yoga. Your answer was wrong.")
    print("The heart chakra is called Anahata Chakra!")

# Question 2 : Dating question - no options the user needs to write a word
# Input
print()
print()
print("Question 2:")
print("What is it you have to feel for the person you are dating after 3 months of dating in order to continue dating this person?")
print("Please answer this question with only one word:")
print()
answer = str(input())
# Calculations
questions += 1
if answer.upper() == "LOVE":
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct_answers / questions) * 100)
# Output
if correct:
    print()
    print("You are very wise in the matters of love - the answer is correct!")
else:
    print()
    print("Remember, that the basis of this universe is Love. Your answer was wrong.")
    print("The correct answer is 'Love'")


# Question 3 : The best game ever made - no options, but the user will get 2 hints
# Input 
print()
print()
print("Question 3:")
print("What is the name of the best game ever made?")
print("Please answer this question with only a one word abbreviation:")
print()
print("Hint 1: There are 3 letters")
print("Hint 2: The protagonist steals a lot of cars")
print()
answer = str(input())
# Calculations
questions += 1
if answer.upper() == "GTA":
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct_answers / questions) * 100)
# Output
if correct:
    print()
    print("You have played a lot of games and have good taste - the answer is correct!")
else:
    print()
    print("Your taste in games is mediocre. Your answer was wrong.")
    print("The correct answer is 'GTA'")

# Question 4 : The most popular Korean food - the user will get 5 korean words and choose the 2 correct words
# Input
print()
print()
print("Question 4:")
print("What is the name of the most popular Korean food?")
print("To succeed you have to combine two of the following words into one word in the correct order:")
print("Bab")
print("Soju")
print("Chi")
print("Bulgogi")
print("Kim")
print()
answer = str(input())
# Calculations
questions += 1
if answer.upper() == "KIMCHI":
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct_answers / questions) * 100)
# Output
if correct:
    print()
    print("You have certainly been eating good Korean food - the answer is correct!")
else:
    print()
    print("You should try one of the tasty Korean restaurants ASAP. Your answer was wrong.")
    print("The correct answer is 'Kimchi'")

# Question 5 : What is the output of this nested loop - how many times will the word Eggs occur?


print()
print()
print("Thank you for playing!")
print()
print("Out of", questions, "questions you have answered", correct_answers, "questions correct.")
# Print the percentage of correct answers
print("Your Quizz Game Total Score is: %6.2f" % percentage, "percent!")
# Out:
# Welcome to the quizz game!
# Try to answer as many questions correct as possible.
# At the end of the quizz you will get your total score in percent of correct answers!
#
# Question 1:
# Which of these chakras is the heart chakra?
# A: Muladhara Chakra
# B: Svadistana Chakra
# C: Manipura Chakra
# D: Anahata Chakra
# E: Vishuddha Chakra
# F: Ajna Chakra
# G: Sahasrara Chakra
#
# d
#
# You must be a yogi - the answer is correct!
#
#
# Question 2:
# What is it you have to feel for the person you are dating after 3 months of dating in order to continue dating this person?
# Please answer this question with only one word:
#
# a
#
# Remember, that the basis of this universe is Love. Your answer was wrong.
# The correct answer is 'Love'
#
#
# Question 3:
# What is the name of the best game ever made?
# Please answer this question with only a one word abbreviation:
#
# Hint 1: There are 3 letters
# Hint 2: The protagonist steals a lot of cars
#
# a
#
# ...

# %%
# Lab 03 - With 5 active questions
# Quizz game program
# Requirements: 1) 5 questions minimum 2) Give feedback to user after they answer a question
# 3) Keep track of the number of correct answers 
# 4) At the end print the percentage of correct answers

# Welcome to the quizz game
print("Welcome to the quizz game!")
# Instructions to the user
print("Try to answer as many questions correct as possible.")
# What the user can expect
print("At the end of the quizz you will get your total score in percent of correct answers!")
print()

# Define variables to be used in the program
questions = 0 # Number of questions asked
correct_answers = 0 # Number of correct answers
correct = 0 # Set to True if the answer is correct
percentage = 0 # The percentage of correct answers is the total score

# Question 1 : Chakras - 7 options
# Input
print("Question 1:")
print("Which of these chakras is the heart chakra? ")
print("A: Muladhara Chakra")
print("B: Svadistana Chakra")
print("C: Manipura Chakra")
print("D: Anahata Chakra")
print("E: Vishuddha Chakra")
print("F: Ajna Chakra")
print("G: Sahasrara Chakra")
print()
answer = str(input())
# Calculations
questions += 1
if answer.upper() == "D":
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct_answers / questions) * 100)
# Output
if correct:
    print()
    print("You must be a yogi - the answer is correct!")
else:
    print()
    print("You should seriously consider practicing more yoga. Your answer was wrong.")
    print("The heart chakra is called Anahata Chakra!")

# Question 2 : Dating question - no options the user needs to write a word
# Input
print()
print()
print("Question 2:")
print("What is it you have to feel for the person you are dating after 3 months of dating in order to continue dating this person?")
print("Please answer this question with only one word:")
print()
answer = str(input())
# Calculations
questions += 1
if answer.upper() == "LOVE":
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct_answers / questions) * 100)
# Output
if correct:
    print()
    print("You are very wise in the matters of love - the answer is correct!")
else:
    print()
    print("Remember, that the basis of this universe is Love. Your answer was wrong.")
    print("The correct answer is 'Love'")


# Question 3 : The best game ever made - no options, but the user will get 2 hints
# Input 
print()
print()
print("Question 3:")
print("What is the name of the best game ever made?")
print("Please answer this question with only a one word abbreviation:")
print()
print("Hint 1: There are 3 letters")
print("Hint 2: The protagonist steals a lot of cars")
print()
answer = str(input())
# Calculations
questions += 1
if answer.upper() == "GTA":
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct_answers / questions) * 100)
# Output
if correct:
    print()
    print("You have played a lot of games and have good taste - the answer is correct!")
else:
    print()
    print("Your taste in games is mediocre. Your answer was wrong.")
    print("The correct answer is 'GTA'")

# Question 4 : The most popular Korean food - the user will get 5 korean words and choose the 2 correct words
# Input
print()
print()
print("Question 4:")
print("What is the name of the most popular Korean food?")
print("To succeed you have to combine two of the following words into one word in the correct order:")
print("Bab")
print("Soju")
print("Chi")
print("Bulgogi")
print("Kim")
print()
answer = str(input())
# Calculations
questions += 1
if answer.upper() == "KIMCHI":
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct_answers / questions) * 100)
# Output
if correct:
    print()
    print("You have certainly been eating good Korean food - the answer is correct!")
else:
    print()
    print("You should try one of the tasty Korean restaurants ASAP. Your answer was wrong.")
    print("The correct answer is 'Kimchi'")

# Question 5 : What is the output of this nested loop - how many times will the word Eggs occur?
# Input
print()
print()
print("Question 5:")
print("Look at the code below, how many times will the word 'Eggs' occur?")
print()
print("for i in range (10):")
print("    print('Eggs')")
print("        for j in range (2):")
print("        print('Eggs')")
print("            for k in range (5):")
print("                print('Eggs')")
print()
print("Your answer should be a number:")
print()
answer = float(input())
# Calculations
questions += 1
if answer == 130 :
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct_answers / questions) * 100)
# Output
if correct:
    print()
    print("You are an exquisite egg lover - the answer is correct!")
else:
    print()
    print("You really need to eat more eggs!. Your answer was wrong. Here you can count the correct number!")
    print()
    egg_count = 0
    for i in range (10):
        egg_count += 1
        print("Eggs", egg_count)
        for j in range (2):
            egg_count += 1
            print("Eggs", egg_count)
            for k in range (5):
                egg_count += 1
                print("Eggs", egg_count)

print()
print()
print("Thank you for playing!")
print()
print("Out of", questions, "questions you have answered", correct_answers, "questions correct.")
# Print the percentage of correct answers
print("Your Quizz Game Total Score is: %6.2f" % percentage, "percent!")
# Out:
# Welcome to the quizz game!
# Try to answer as many questions correct as possible.
# At the end of the quizz you will get your total score in percent of correct answers!
#
# Question 1:
# Which of these chakras is the heart chakra?
# A: Muladhara Chakra
# B: Svadistana Chakra
# C: Manipura Chakra
# D: Anahata Chakra
# E: Vishuddha Chakra
# F: Ajna Chakra
# G: Sahasrara Chakra
#
# a
#
# You should seriously consider practicing more yoga. Your answer was wrong.
# The heart chakra is called Anahata Chakra!
#
#
# Question 2:
# What is it you have to feel for the person you are dating after 3 months of dating in order to continue dating this person?
# Please answer this question with only one word:
#
# love
#
# You are very wise in the matters of love - the answer is correct!
#
#
# Question 3:
# What is the name of the best game ever made?
# Please answer this question with only a one word abbreviation:
#
# Hint 1: There are 3 letters
# Hint 2: The protagonist steals a lot of cars
#
# gta
# ...

# %%
# Work cell before combining all 5 questions into the full program

# Define variables
questions = 0
correct_answers = 0
correct = 0
score_percentage = 0
# Question 1 : Chakras
# Input
print("Which of these chakras is the heart chakra? ")
print("A: Muladhara")
print("B: Svadistana")
print("C: Manipura")
print("D: Anahata")
print("E: Vishuddha")
print("F: Ajna")
print("G: Sahasrara")
print()
answer = str(input())
# Calculations
questions += 1
if answer.upper() == "D":
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct / questions) * 100)

# Output
if correct:
    print()
    print("You must be a yogi - the answer is correct!")
else:
    print()
    print("You should seriously consider practicing more yoga. Your answer was wrong.")
    print("The heart chakra is called Anahata!")
print()
print("Out of", questions, "questions you have answered", correct_answers, "questions correct.")
print("Your percentage of correct answers is:", percentage, "percent!")
# Out:
# Which of these chakras is the heart chakra?
# A: Muladhara
# B: Svadistana
# C: Manipura
# D: Anahata
# E: Vishuddha
# F: Ajna
# G: Sahasrara
#
# a
#
# You should seriously consider practicing more yoga. Your answer was wrong.
# The heart chakra is called Anahata!
#
# Out of 1 questions you have answered 0 questions correct.
# Your percentage of correct answers is: 0.0 percent!

# %%
# Work cell before combining all 5 questions into the full program

# Question 2 : Dating question - no options the user needs to write a word
# Input
print("What is it you have to feel for the person you are dating after 3 months of dating in order to continue dating this person?")
print("Please answer this question with only one word:")
print()
answer = str(input())
# Calculations
questions += 1
if answer.upper() == "LOVE":
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct / questions) * 100)
# Output
if correct:
    print()
    print("You are very wise in the matters of love - the answer is correct!")
else:
    print()
    print("Remember, that the basis of this universe is Love. Your answer was wrong.")
    print("The correct answer is 'Love'")
# Out:
# What is it you have to feel for the person you are dating after 3 months of dating in order to continue dating this person?
# Please answer this question with only one word:
#
# a
#
# Remember, that the basis of this universe is Love. Your answer was wrong.
# The correct answer is 'Love'

# %%
# Work cell before combining all 5 questions into the full program

# Question 3 : The best game ever made - no options, but the user will get 2 hints
# Input 
print("What is the name of the best game ever made?")
print("Please answer this question with only a one word abbreviation:")
print()
print("Hint 1: There are 3 letters")
print("Hint 2: The protagonist steals a lot of cars")
print()
answer = str(input())
# Calculations
questions += 1
if answer.upper() == "GTA":
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct / questions) * 100)
# Output
if correct:
    print()
    print("You have played a lot of games and have good taste - the answer is correct!")
else:
    print()
    print("Your taste in games is mediocre. Your answer was wrong.")
    print("The correct answer is 'GTA'")
# Out:
# What is the name of the best game ever made?
# Please answer this question with only a one word abbreviation:
#
# Hint 1: There are 3 letters
# Hint 2: The protagonist steals a lot of cars
#
# GtA
#
# You have played a lot of games and have good taste - the answer is correct!

# %%
# Work cell before combining all 5 questions into the full program

# Question 4 : The most popular Korean food - the user will get 5 korean words and choose the 2 correct words
# Input
print("What is the name of the most popular Korean food?")
print("To succeed you have to combine two of the following words into one word in the correct order:")
print("Bab")
print("Soju")
print("Chi")
print("Bulgogi")
print("Kim")
print()
answer = str(input())
# Calculations
questions += 1
if answer.upper() == "KIMCHI":
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct / questions) * 100)
# Output
if correct:
    print()
    print("You have certainly been eating good Korean food - the answer is correct!")
else:
    print()
    print("You should try one of the tasty Korean restaurants ASAP. Your answer was wrong.")
    print("The correct answer is 'Kimchi'")
# Out:
# What is the name of the most popular Korean food?
# To succeed you have to combine two of the following words into one word in the correct order:
# Bab
# Soju
# Chi
# Bulgogi
# Kim
#
# kimchi
#
# You have certainly been eating good Korean food - the answer is correct!

# %%
# Work cell before combining all 5 questions into the full program

# Question 5 : What is the output of this nested loop - how many times will the word Eggs occur?
# Input
print("Look at the code below, how many times will the word 'Eggs' occur?")
print()
print("for i in range (10):")
print("    print('Eggs')")
print("        for j in range (2):")
print("        print('Eggs')")
print("            for k in range (5):")
print("                print('Eggs')")
print()
print("Your answer should be a number:")
print()
answer = float(input())
# Calculations
questions += 1
if answer == 130 :
    correct = True
# Keep track of the number of correct answers
    correct_answers += 1
else:
    correct = False
percentage = float((correct / questions) * 100)
# Output
if correct:
    print()
    print("You are an exquisite egg lover - the answer is correct!")
else:
    print()
    print("You really need to eat more eggs!. Your answer was wrong. Here you can count the correct number!")
    egg_count = 0
    for i in range (10):
        egg_count += 1
        print("Eggs", egg_count)
        for j in range (2):
            egg_count += 1
            print("Eggs", egg_count)
            for k in range (5):
                egg_count += 1
                print("Eggs", egg_count)
# Out:
# Look at the code below, how many times will the word 'Eggs' occur?
#
# for i in range (10):
#     print('Eggs')
#         for j in range (2):
#         print('Eggs')
#             for k in range (5):
#                 print('Eggs')
#
# Your answer should be a number:
#
# 3
#
# You really need to eat more eggs!. Your answer was wrong. Here you can count the correct number!
# Eggs 1
# Eggs 2
# Eggs 3
# Eggs 4
# Eggs 5
# Eggs 6
# Eggs 7
# Eggs 8
# Eggs 9
# Eggs 10
# Eggs 11
# Eggs 12
# Eggs 13
# Eggs 14
# Eggs 15
# Eggs 16
# Eggs 17
# Eggs 18
# Eggs 19
# Eggs 20
# Eggs 21
# Eggs 22
# Eggs 23
# Eggs 24
# Eggs 25
# Eggs 26
# Eggs 27
# Eggs 28
# Eggs 29
# Eggs 30
# Eggs 31
# Eggs 32
# Eggs 33
# Eggs 34
# Eggs 35
# Eggs 36
# Eggs 37
# Eggs 38
# Eggs 39
# Eggs 40
# Eggs 41
# Eggs 42
# Eggs 43
# Eggs 44
# Eggs 45
# Eggs 46
# Eggs 47
# Eggs 48
# Eggs 49
# Eggs 50
# Eggs 51
# Eggs 52
# Eggs 53
# Eggs 54
# Eggs 55
# Eggs 56
# Eggs 57
# Eggs 58
# Eggs 59
# Eggs 60
# Eggs 61
# Eggs 62
# Eggs 63
# ...
